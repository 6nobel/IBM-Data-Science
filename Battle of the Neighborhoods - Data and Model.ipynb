# %% [markdown]
# ### Introduction
#
# Welcome! This is the coding, visualization and Modeling part of the part of the project!
#
# Basic approach here is to get the data needed from foursquare, visualize it, check if the data is sufficient and maybe repeat some of the process, then we try different clustering algorithms and evaluate those, to hopefully come to a conclusion!
#
# Important comment: We will be working with the k-means algorithm a lot. As this algorithm is based on random starting points at the start of the algorithm, numbers and results might be different if the code is re-run from when I ran them originally!
#
# Lets dive into it:

# %%
# getting libraries needed
import requests
import pandas as pd 
import numpy as np 
import time
    
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium
print('Success! Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.6.20-hecda079_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0        conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Success! Libraries imported.

# %% [markdown]
# lets start off by visualizing the trade area of the business:

# %%
# starting a Folium map around the area:
map_ostfriesland = folium.Map(location=[53.23, 7.47], zoom_start=9)

# starting a list of points that mark the corner of the area
points = [[53.24, 7.21], [53.03, 7.21], [53.03, 8.57], [53.83, 8.57], [53.83, 6.07], [53.24, 7.21]]

# draw points
for each in points:  
    map_ostfriesland.add_child(folium.CircleMarker(location=each,
    fill='true',
    radius = 6,
    popup= str(each),
    fill_color='blue',
    color = 'clear',
    fill_opacity=1))

# add lines between the points
folium.PolyLine(points, color="blue", weight=2.5, opacity=1).add_to(map_ostfriesland)    

# lets draw the map!
map_ostfriesland
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# that looks like a challenge to get all the venues in that trade area, as its not circular or rectangular. As forsquare is working with a radius, and maximum 50 results per search, lets map several circles within the trade area to keep the result lists below 50:

# %%
# starting a Folium map around the area:
map_ostfriesland2 = folium.Map(location=[53.23, 7.47], zoom_start=9)

# starting a list of points that mark the corner of the area
points = [[53.24, 7.21], [53.03, 7.21], [53.03, 8.57], [53.83, 8.57], [53.83, 6.07], [53.24, 7.21]]

# draw points
for each in points:  
    map_ostfriesland2.add_child(folium.CircleMarker(location=each,
    fill='true',
    radius = 6,
    popup= 'Hi',
    fill_color='blue',
    color = 'clear',
                                                    
    fill_opacity=1))

# add lines between the points
folium.PolyLine(points, color="blue", weight=2.5, opacity=1).add_to(map_ostfriesland2)   

#creating empty list and variable for the loop
lon_factor=0
searchpoints=[]

# adding circles
for i in range(6):
    lon_factor+=0.33
    lat_factor=0
    for j in range(4):
        searchpoints.append([53.69+lat_factor, 6.45+lon_factor])
        map_ostfriesland2.add_child(folium.Circle(location=[53.69+lat_factor, 6.45+lon_factor], radius=15000,
                    line_color='red', fill_opacity = 0.3, fill='true',
                    fill_color='yellow'))
        lat_factor-=0.19
        

# lets draw the map!
map_ostfriesland2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 24 circles with a radius of 15km seems to get all the area, but also a lot more - we will have to do some cleaning on the data!
#
# Lets get foursquare set up with the needed parameters and start our search:

# %%
# setting up the Foursquare API paramenters:

#login credentials
CLIENT_ID = '4PNCQ5FGSPM5OJ1L0AYGTZWTAIOYAMSFTVRS0EFZQ02JU3VL' # your Foursquare ID
CLIENT_SECRET = 'JNKEW3N0WX1LEXFX0BJHIZKEBD5PXE30NNGYANZRFVYDTYV5' # your Foursquare Secret
VERSION = '20200620'

# lets start off by looking at restaurants, and a radius of 15km around each ccordinate 
search_query = 'Restaurant'
radius = 15000

#create empty pandas dataframe
df = pd.DataFrame()

# with a loop, we do one search for each of the 24 coordinate pairs, printing the coordinates and shapes to see how many restaurants we find:
for ll in searchpoints:
    print(ll)
    # calling the API
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, ll[0], ll[1], VERSION, search_query, radius)
    results = requests.get(url).json()
    # assign relevant part of JSON to venues
    venues = results['response']['venues']
    # tranform venues into a dataframe
    df_temp = json_normalize(venues)
    print(df_temp.shape)
    # add the current local search to the overall result list
    df = df.append(df_temp, sort=True)
    # sleep to not spam the API
    time.sleep(1)
# Out:
# [53.69, 6.78]
# (14, 16)
# [53.5, 6.78]
# (20, 16)
# [53.309999999999995, 6.78]
# (30, 17)
# [53.12, 6.78]
# (30, 18)
# [53.69, 7.11]
# (30, 17)
# [53.5, 7.11]
# (29, 17)
# [53.309999999999995, 7.11]
# (29, 18)
# [53.12, 7.11]
# (29, 16)
# [53.69, 7.44]
# (21, 19)
# [53.5, 7.44]
# (10, 16)
# [53.309999999999995, 7.44]
# (28, 18)
# [53.12, 7.44]
# (30, 18)
# [53.69, 7.7700000000000005]
# (24, 19)
# [53.5, 7.7700000000000005]
# (12, 16)
# [53.309999999999995, 7.7700000000000005]
# (6, 16)
# [53.12, 7.7700000000000005]
# (9, 16)
# [53.69, 8.1]
# (22, 18)
# [53.5, 8.1]
# (30, 19)
# [53.309999999999995, 8.1]
# (26, 17)
# [53.12, 8.1]
# (30, 17)
# [53.69, 8.43]
# (8, 18)
# [53.5, 8.43]
# (30, 18)
# [53.309999999999995, 8.43]
# (13, 16)
# [53.12, 8.43]
# (30, 18)

# %%
# we repeat this process with a search query for 'Cafe' as well:
search_query = 'Cafe'
for ll in searchpoints:
    print(ll)
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, ll[0], ll[1], VERSION, search_query, radius)
    results = requests.get(url).json()
    venues = results['response']['venues']
    df_temp = json_normalize(venues)
    print(df_temp.shape)
    df = df.append(df_temp, sort=True)
    time.sleep(1)
# Out:
# [53.69, 6.78]
# (21, 17)
# [53.5, 6.78]
# (28, 18)
# [53.309999999999995, 6.78]
# (30, 18)
# [53.12, 6.78]
# (30, 17)
# [53.69, 7.11]
# (21, 17)
# [53.5, 7.11]
# (30, 18)
# [53.309999999999995, 7.11]
# (30, 19)
# [53.12, 7.11]
# (30, 16)
# [53.69, 7.44]
# (19, 18)
# [53.5, 7.44]
# (6, 16)
# [53.309999999999995, 7.44]
# (30, 18)
# [53.12, 7.44]
# (30, 17)
# [53.69, 7.7700000000000005]
# (30, 18)
# [53.5, 7.7700000000000005]
# (11, 17)
# [53.309999999999995, 7.7700000000000005]
# (6, 17)
# [53.12, 7.7700000000000005]
# (11, 16)
# [53.69, 8.1]
# (19, 17)
# [53.5, 8.1]
# (30, 18)
# [53.309999999999995, 8.1]
# (30, 18)
# [53.12, 8.1]
# (30, 18)
# [53.69, 8.43]
# (7, 17)
# [53.5, 8.43]
# (30, 19)
# [53.309999999999995, 8.43]
# (13, 18)
# [53.12, 8.43]
# (30, 18)

# %%
#we copy the df, so we have a clean copy of the original dataframe so we can play around with the data without having to recall the API needlessly in case we need the original data.
df_clean = df.copy()

#reset the index:
df_clean.reset_index(inplace=True)
df_clean
# Out:
#       index                                         categories  hasPerk  \
# 0         0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1         1  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 2         2  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 3         3  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 4         4  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...    False
# 5         5  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 6         6  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 7         7  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...    False
# 8         8  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 9         9  [{'id': '4bf58dd8d48988d155941735', 'name': 'G...    False
# 10       10  [{'id': '4bf58dd8d48988d155941735', 'name': 'G...    False
# 11       11  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 12       12  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...    False
# 13       13  [{'id': '4bf58dd8d48988d1c0941735', 'name': 'M...    False
# 14        0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 15        1  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...    False
# 16        2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 17        3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 18        4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 19        5  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 20        6  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 21        7  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 22        8  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 23        9  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 24       10  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...    False
# 25       11  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 26       12                                                 []    False
# 27       13  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...    False
# 28       14  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...    False
# 29       15  [{'id': '4bf58dd8d48988d10d941735', 'name': 'G...    False
# ...     ...                                                ...      ...
# 1301      0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1302      1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1303      2  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 1304      3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1305      4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1306      5  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1307      6  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1308      7  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1309      8  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1310      9  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...    False
# 1311     10  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1312     11  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 1313     12  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1314     13  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 1315     14  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1316     15  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1317     16  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 1318     17  [{'id': '52e81612bcbc57f1066b7a00', 'name': 'C...    False
# 1319     18  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1320     19  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1321     20  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1322     21  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1323     22  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1324     23  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1325     24  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1326     25  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1327     26  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1328     27  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1329     28  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1330     29  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
#
#                             id              location.address location.cc  \
# 0     55e2ffd5498ed6652fc8eb5d                           NaN          DE
# 1     51f550cf498e29a9dc99986f                           NaN          DE
# 2     50521591e4b0d453755ceed3                           NaN          DE
# 3     4ebc17d3be7b329d90ba532d                           NaN          DE
# 4     4ffed466e4b002ba9a0b971e                           NaN          DE
# 5     513b9e25e4b02424670f5926          Jann-Berghaus-Str.63          DE
# 6     599b0df4419a9e32cdaef1b0               Süderstrasse 69          DE
# 7     4e69ecca1f6e1e74e3fb228b                           NaN          DE
# 8     4ffee479e4b0092e51a67fe2  Roelof-Gerritz-Meyer-Str. 10          DE
# 9     555502a8498ea54200dd3155             Hindenburgstr. 97          DE
# 10    538def98498ed2e9e7656e47               Bismarckstr. 18          DE
# 11    4de1343d52b1c1b3ce463924                    Am Hafen 1          DE
# 12    51ac818e498ecb835364dae0              Am Neuen Hafen 2          DE
# 13    4e664c3ed164ddd5e7639096                  Neue Str. 12          DE
# 14    5d29c650e97aae002d1bd70d                           NaN          NL
# 15    4ffed466e4b002ba9a0b971e                           NaN          DE
# 16    4d8a468d4757721effcdb369                    Radsweg 12          NL
# 17    55e2ffd5498ed6652fc8eb5d                           NaN          DE
# 18    599b0df4419a9e32cdaef1b0               Süderstrasse 69          DE
# 19    50521591e4b0d453755ceed3                           NaN          DE
# 20    51f550cf498e29a9dc99986f                           NaN          DE
# 21    4ebc17d3be7b329d90ba532d                           NaN          DE
# 22    4fcb50a3e4b057a7eee0aa98                    Menkemaweg          NL
# 23    513b9e25e4b02424670f5926          Jann-Berghaus-Str.63          DE
# 24    4fa92811e4b099106f747db3                           N33          NL
# 25    53d50dcf498eb6c95167b65c                   Schoolweg 4          NL
# 26    4e3ebe69aeb73139a18a1b99                 Hooilandseweg          NL
# 27    51ac818e498ecb835364dae0              Am Neuen Hafen 2          DE
# 28    4ffee479e4b0092e51a67fe2  Roelof-Gerritz-Meyer-Str. 10          DE
# 29    4e69ecca1f6e1e74e3fb228b                           NaN          DE
# ...                        ...                           ...         ...
# 1301  5afd98d9dff815002caf2c36                Parkstrasse 64          DE
# 1302  51262022e4b0857bf36cdc73                 Parkstraße 64          DE
# 1303  5a6f40f21213847e736add48                           NaN          DE
# ...                                                 ...
# 1301          [Parkstrasse 64, 27798 Hude, Deutschland]
# 1302           [Parkstraße 64, 27798 Hude, Deutschland]
# 1303                                      [Deutschland]
# 1304                                      [Deutschland]
# 1305  [Alexanderstraße 119, 26121 Oldenburg, Deutsch...
# 1306                                      [Deutschland]
# 1307          [Weserstraße 3, 27804 Berne, Deutschland]
# 1308                [Iprump 3, 27798 Hude, Deutschland]
# 1309       [Langestr. 31, 26122 Oldenburg, Deutschland]
# 1310                                      [Deutschland]
# 1311     [Theaterwall 47, 26121 Oldenburg, Deutschland]
# 1312            [Markt 4, 26122 Oldenburg, Deutschland]
# 1313                        [28757 Bremen, Deutschland]
# 1314  [Donnerschweer Straße 280, 26123 Oldenburg, De...
# 1315                                      [Deutschland]
# 1316       [Am Markt 2-3, 26122 Oldenburg, Deutschland]
# 1317                     [27809 Lemwerder, Deutschland]
# 1318   [Flughafenstr. 3a, 27809 Lemwerder, Deutschland]
# 1319            [Damm 36, 26135 Oldenburg, Deutschland]
# 1320       [Staugraben 9, 26122 Oldenburg, Deutschland]
# 1321      [Bürgerstr. 52, 26123 Oldenburg, Deutschland]
# 1322        [Karlstr. 25, 26123 Oldenburg, Deutschland]
# 1323                           [Oldenburg, Deutschland]
# 1324  [Lange Str. 90 (Wallstr.), 26122 Oldenburg, De...
# 1325  [Am Stadtmuseum 4–8, 26121 Oldenburg, Deutschl...
# 1326     [Schlossplatz 1, 26122 Oldenburg, Deutschland]
# 1327                                      [Deutschland]
# 1328   [Baumgartenstr. 4, 26122 Oldenburg, Deutschland]
# 1329                           [Oldenburg, Deutschland]
# 1330                                      [Deutschland]
#
#                                 location.labeledLatLngs  location.lat  \
# 0     [{'label': 'display', 'lat': 53.591618, 'lng':...     53.591618
# 1     [{'label': 'display', 'lat': 53.59354782104492...     53.593548
# 2     [{'label': 'display', 'lat': 53.58814211906586...     53.588142
# 3     [{'label': 'display', 'lat': 53.589037, 'lng':...     53.589037
# 4     [{'label': 'display', 'lat': 53.58511322759146...     53.585113
# 5     [{'label': 'display', 'lat': 53.59028186130264...     53.590282
# 6     [{'label': 'display', 'lat': 53.58098, 'lng': ...     53.580980
# 7     [{'label': 'display', 'lat': 53.604226133449, ...     53.604226
# 8     [{'label': 'display', 'lat': 53.58788336997905...     53.587883
# 9     [{'label': 'display', 'lat': 53.5956572089344,...     53.595657
# 10    [{'label': 'display', 'lat': 53.58708572387695...     53.587086
# 11    [{'label': 'display', 'lat': 53.67427034964978...     53.674270
# 12    [{'label': 'display', 'lat': 53.55941, 'lng': ...     53.559410
# 13    [{'label': 'display', 'lat': 53.58712843198619...     53.587128
# 14    [{'label': 'display', 'lat': 53.44386, 'lng': ...     53.443860
# 15    [{'label': 'display', 'lat': 53.58511322759146...     53.585113
# 16    [{'label': 'display', 'lat': 53.41394, 'lng': ...     53.413940
# 17    [{'label': 'display', 'lat': 53.591618, 'lng':...     53.591618
# 18    [{'label': 'display', 'lat': 53.58098, 'lng': ...     53.580980
# 19    [{'label': 'display', 'lat': 53.58814211906586...     53.588142
# 20    [{'label': 'display', 'lat': 53.59354782104492...     53.593548
# 21    [{'label': 'display', 'lat': 53.589037, 'lng':...     53.589037
# 22    [{'label': 'display', 'lat': 53.40545654296875...     53.405457
# 23    [{'label': 'display', 'lat': 53.59028186130264...     53.590282
# 24    [{'label': 'display', 'lat': 53.37257890245485...     53.372579
# 25    [{'label': 'display', 'lat': 53.336779, 'lng':...     53.336779
# 26    [{'label': 'display', 'lat': 53.42045046666667...     53.420450
# 27    [{'label': 'display', 'lat': 53.55941, 'lng': ...     53.559410
# 28    [{'label': 'display', 'lat': 53.58788336997905...     53.587883
# 29    [{'label': 'display', 'lat': 53.604226133449, ...     53.604226
# ...                                                 ...           ...
# 1301  [{'label': 'display', 'lat': 53.114585, 'lng':...     53.114585
# 1302  [{'label': 'display', 'lat': 53.11459732055664...     53.114597
# 1303  [{'label': 'display', 'lat': 53.191402, 'lng':...     53.191402
# 1304  [{'label': 'display', 'lat': 53.152993, 'lng':...     53.152993
# 1305  [{'label': 'display', 'lat': 53.15608691695047...     53.156087
# 1306  [{'label': 'display', 'lat': 53.09615397757142...     53.096154
# 1307  [{'label': 'display', 'lat': 53.176748, 'lng':...     53.176748
# 1308  [{'label': 'display', 'lat': 53.149322, 'lng':...     53.149322
# 1309  [{'label': 'display', 'lat': 53.14054687186161...     53.140547
# 1310  [{'label': 'display', 'lat': 53.09574127197265...     53.095741
# 1311  [{'label': 'display', 'lat': 53.14112919551392...     53.141129
# 1312  [{'label': 'display', 'lat': 53.1391076660456,...     53.139108
# 1313  [{'label': 'display', 'lat': 53.170304, 'lng':...     53.170304
# 1314  [{'label': 'display', 'lat': 53.15440845518945...     53.154408
# 1315  [{'label': 'display', 'lat': 53.12683486938476...     53.126835
# 1316  [{'label': 'display', 'lat': 53.13922066654736...     53.139221
# 1317  [{'label': 'display', 'lat': 53.16358174536471...     53.163582
# 1318  [{'label': 'display', 'lat': 53.16212424618705...     53.162124
# 1319  [{'label': 'display', 'lat': 53.13454801801271...     53.134548
# 1320  [{'label': 'display', 'lat': 53.14230434436891...     53.142304
# 1321  [{'label': 'display', 'lat': 53.15337386292067...     53.153374
# 1322  [{'label': 'display', 'lat': 53.14556057057482...     53.145561
# 1323  [{'label': 'display', 'lat': 53.1386833190918,...     53.138683
# 1324  [{'label': 'display', 'lat': 53.14288475232893...     53.142885
# 1325  [{'label': 'display', 'lat': 53.14419826251238...     53.144198
# 1326  [{'label': 'display', 'lat': 53.13154053346515...     53.131541
# 1327  [{'label': 'display', 'lat': 53.10717721970144...     53.107177
# 1328  [{'label': 'display', 'lat': 53.1398893650148,...     53.139889
# 1329  [{'label': 'display', 'lat': 53.14426040649414...     53.144260
# 1330  [{'label': 'display', 'lat': 53.139268, 'lng':...     53.139268
#
#       location.lng location.neighborhood location.postalCode location.state  \
# 0         6.694292                   NaN                 NaN            NaN
# 1         6.664623                   NaN                 NaN            NaN
# 2         6.663512                   NaN                 NaN            NaN
# 3         6.664241                   NaN                 NaN  Niedersachsen
# 4         6.691201                   NaN                 NaN            NaN
# 5         6.660200                   NaN               26757  Niedersachsen
# 6         6.667349                   NaN               26757  Niedersachsen
# 6                           Restaurant Südhauk  v-1592752936          NaN
# 7                      Café Restaurant Ostland  v-1592752936          NaN
# 8                   Cafe Restaurant Alt Borkum  v-1592752936          NaN
# 9                    Café Restaurant Bar Alibi  v-1592752936          NaN
# 10                 Schmitt Restaurant Bar Cafe  v-1592752936          NaN
# 11                            Hafen Restaurant  v-1592752936          NaN
# 12                       Yachthafen Restaurant  v-1592752936          NaN
# 13                                  Valentin's  v-1592752936          NaN
# 14                          Restaurant Diekgat  v-1592752937          NaN
# 15                   Restaurant Zum Yachthafen  v-1592752937          NaN
# 16                    Hotel Restaurant Ekamper  v-1592752937          NaN
# 17                 Restaurant Café Geflügelhof  v-1592752937          NaN
# 18                          Restaurant Südhauk  v-1592752937          NaN
# 19                          Restaurant Seehund  v-1592752937          NaN
# 20                         Restaurant Zum Kaap  v-1592752937          NaN
# 21                   Restaurant Austernfischer  v-1592752937          NaN
# 22                     Restaurant 't Schathoes  v-1592752937          NaN
# 23                            Restaurant Palée  v-1592752937          NaN
# 24                        Restaurant Eemshaven  v-1592752937          NaN
# 25                        Restaurant Veldzicht  v-1592752937          NaN
# 26            Chinees restaurant Golden Garden  v-1592752937          NaN
# 27                       Yachthafen Restaurant  v-1592752937          NaN
# 28                  Cafe Restaurant Alt Borkum  v-1592752937          NaN
# 29                     Café Restaurant Ostland  v-1592752937          NaN
# ...                                        ...           ...          ...
# 1301                     le café Behrens-Meyer  v-1592753032          NaN
# 1302                     Café "Leib und Seele"  v-1592753032          NaN
# 1303            Cafe Blomendal (Starke Bäcker)  v-1592753032          NaN
# 1304                                   Cafe 21  v-1592753032          NaN
# 1305                Café und Konditorei Klinge  v-1592753032          NaN
# 1306                          Cafe am Hasbruch  v-1592753032          NaN
# 1307                              Café Kückens  v-1592753032          NaN
# 1308                          Café Huntewasser  v-1592753032          NaN
# 1309               Stadtbäckerei Cafe Schröder  v-1592753032          NaN
# 1310                         Eis—Cafe San Remo  v-1592753032          NaN
# 1311                               Cafe Klinge  v-1592753032          NaN
# 1312                         Café & Bar Celona  v-1592753032          NaN
# 1313                                Café Coppa  v-1592753032          NaN
# 1314                     le café Behrens-Meyer  v-1592753032          NaN
# 1315                                    Café M  v-1592753032          NaN
# 1316                              Cafe Florian  v-1592753032          NaN
# 1317                                Cafe Garde  v-1592753032          NaN
# 1318           Café Restaurant Weser Yachtclub  v-1592753032          NaN
# 1319                              Café Am Damm  v-1592753032          NaN
# 1320                         Café Grünstreifen  v-1592753032          NaN
# 1321  Café - Restaurant besünners | Cassellius  v-1592753032          NaN
# 1322                          Cafe Kurswechsel  v-1592753032          NaN
# 1323                       Café im Lambertihof  v-1592753032          NaN
# 1324                           Café Extrablatt  v-1592753032          NaN
# 1325                          Cafe Farbwechsel  v-1592753032          NaN
# 1326                           Café im Schloss  v-1592753032          NaN
# 1327              Möbel Buss-Familien Café Bar  v-1592753032          NaN
# 1328                           Cafe Innenleben  v-1592753032          NaN
# 1329                            Café Sonneneck  v-1592753032          NaN
# 1330                            Café Oldenburg  v-1592753032          NaN
#
# [1331 rows x 20 columns]

# %%
#drop all columns that are not needed for the problem we are trying to solve
df_clean2 = df_clean.loc[:, ['name', 'id', 'categories', 'location.lat', 'location.lng']]

# %%
# lets do a quick helper function to extract the categories out of the list currently saved there
def get_category_type(row):
    categories_list = row['categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# and lets call the funtion to get a clean category
df_clean2['categories'] = df_clean2.apply(get_category_type, axis=1)

df_clean2.head()
# Out:
#                           name                        id          categories  \
# 0  Restaurant Café Geflügelhof  55e2ffd5498ed6652fc8eb5d                Café
# 1          Restaurant Zum Kaap  51f550cf498e29a9dc99986f  Seafood Restaurant
# 2           Restaurant Seehund  50521591e4b0d453755ceed3  Seafood Restaurant
# 3    Restaurant Austernfischer  4ebc17d3be7b329d90ba532d  Seafood Restaurant
# 4    Restaurant Zum Yachthafen  4ffed466e4b002ba9a0b971e   German Restaurant
#
#    location.lat  location.lng
# 0     53.591618      6.694292
# 1     53.593548      6.664623
# 2     53.588142      6.663512
# 3     53.589037      6.664241
# 4     53.585113      6.691201

# %%
# and drop duplicates and reset index
df_clean2.drop_duplicates(subset=['id'], inplace=True)
df_clean2.reset_index(inplace=True)
df_clean2 = df_clean2.loc[:, ['name', 'id', 'categories', 'location.lat', 'location.lng']]
df_clean2
# Out:
#                                                   name  \
# 0                          Restaurant Café Geflügelhof
# 1                                  Restaurant Zum Kaap
# 2                                   Restaurant Seehund
# 3                            Restaurant Austernfischer
# 4                            Restaurant Zum Yachthafen
# 5                                     Restaurant Palée
# 6                                   Restaurant Südhauk
# 7                              Café Restaurant Ostland
# 8                           Cafe Restaurant Alt Borkum
# 9                            Café Restaurant Bar Alibi
# 10                         Schmitt Restaurant Bar Cafe
# 11                                    Hafen Restaurant
# 12                               Yachthafen Restaurant
# 13                                          Valentin's
# 14                                  Restaurant Diekgat
# 15                            Hotel Restaurant Ekamper
# 16                             Restaurant 't Schathoes
# 17                                Restaurant Eemshaven
# 18                                Restaurant Veldzicht
# 19                    Chinees restaurant Golden Garden
# 20                              Dunia Grill Restaurant
# 21                             Restaurant Het Regthuys
# 22                                 Restaurant You - Yi
# 23                 Grandcafé Restaurant 'Bij de Molen'
# 24                          Restaurant Boven Groningen
# 25                            Restaurant Fraeylemaborg
# 26                              Restaurant de Kakebrug
# 27                                  Restaurant Est Est
# 28                                 Restaurant West CPD
# 29                           Restaurant de Boegschroef
# ..                                                 ...
# 692                                        Café Brüser
# 693                                        Cafe Albers
# 694                                        Café Carlos
# 695                                         Café David
# 696                                   Cafe Engelbrecht
# 697                                      Café de Fiets
# 698                                SNACK-CAFE SUNSHINE
# 699                                   Eis-Café Cortina
# 700                                 Alexis Bistro Cafe
# 701                                      Milchbar Café
# 702                                   Taverna Da Vinci
# 703                                 Caféteriá Pyramide
# 704                     Cafe Blomendal (Starke Bäcker)
# 705                                   Cafe Zum Fischer
# 706                                       Fischer Café
# 707                            FischerCafé - Landhotel
# 708                                       Café Kückens
# 709                                            Cafe 21
# 710                                         Café Coppa
# 711  Starke Bäcker Café 1868 Am Schwaneweder Marktp...
# 712                                  Dem Cafe Vegesack
# 713                              le café Behrens-Meyer
# 714                              Café "Leib und Seele"
# 715                                   Cafe am Hasbruch
# 716                                   Café Huntewasser
# 717                                  Eis—Cafe San Remo
# 718                              le café Behrens-Meyer
# 719                                         Cafe Garde
# 720                                   Cafe Kurswechsel
# 721                       Möbel Buss-Familien Café Bar
#
#                            id                categories  location.lat  \
# 0    55e2ffd5498ed6652fc8eb5d                      Café     53.591618
# 1    51f550cf498e29a9dc99986f        Seafood Restaurant     53.593548
# 2    50521591e4b0d453755ceed3        Seafood Restaurant     53.588142
# 3    4ebc17d3be7b329d90ba532d        Seafood Restaurant     53.589037
# 4    4ffed466e4b002ba9a0b971e         German Restaurant     53.585113
# 5    513b9e25e4b02424670f5926                Restaurant     53.590282
# 6    599b0df4419a9e32cdaef1b0                Restaurant     53.580980
# 7    4e69ecca1f6e1e74e3fb228b         German Restaurant     53.604226
# 8    4ffee479e4b0092e51a67fe2        Seafood Restaurant     53.587883
# 9    555502a8498ea54200dd3155                 Gastropub     53.595657
# 10   538def98498ed2e9e7656e47                 Gastropub     53.587086
# 11   4de1343d52b1c1b3ce463924        Seafood Restaurant     53.674270
# 12   51ac818e498ecb835364dae0         German Restaurant     53.559410
# 13   4e664c3ed164ddd5e7639096  Mediterranean Restaurant     53.587128
# 14   5d29c650e97aae002d1bd70d                Restaurant     53.443860
# 15   4d8a468d4757721effcdb369                     Hotel     53.413940
# 16   4fcb50a3e4b057a7eee0aa98                Restaurant     53.405457
# 17   4fa92811e4b099106f747db3                     Diner     53.372579
# 18   53d50dcf498eb6c95167b65c                Restaurant     53.336779
# 19   4e3ebe69aeb73139a18a1b99                      None     53.420450
# 20   4cb0df2edb32f04d89b8c34d               Snack Place     53.407739
# 21   4c7a7bc7794e224b269a6828                Restaurant     53.323301
# 22   4d57c920afe4b60c38d24861        Chinese Restaurant     53.322425
# 23   4c4ae80f6e209521bde1edeb                Restaurant     53.300148
# 24   5087b4aae4b0c4120eeb39c1                     Diner     53.333646
# 25   4dcc0653e4cde609a3a6224f                Restaurant     53.215810
# 26   4c1b18f23b2ab713be163325                     Diner     53.331540
# 27   5644e8f1498edda47ca5e5fe                Restaurant     53.217380
# 28   528c9a75498e974ec3b159eb                     Diner     53.316300
# 29   5352c7ab498e9488311e6376                Restaurant     53.331715
# ..                        ...                       ...           ...
# 692  51642bc7e4b0dd203ce24a5c                      Café     53.522274
# 693  528e200f498e7e361e4c55c5                      Café     53.402127
# 694  53204928498ee21029a977bf     Portuguese Restaurant     53.550475
# 695  58b0e4cd4287c926c6821b15           Other Nightlife     53.553760
# 696  4c289759ce3fc92858556d88                      Café     53.543869
# 697  4b586f41f964a5208f5728e3                 Rock Club     53.553331
# 698  4c7d1cf3978976b005c8e939               Snack Place     53.552776
# 699  50e1b2f4e4b075c2f3b4c68d            Ice Cream Shop     53.546080
# 700  4f980713e4b0bae926b0bd53                      Café     53.557987
# 701  5b9d3a86e1f228002c6f40fa                      Café     53.548176
# 702  4e51003b1f6eae4d252f70c6         Trattoria/Osteria     53.541584
# 703  4f02129402d580f8f1e8f6e3                Hookah Bar     53.552286
# 704  5a6f40f21213847e736add48                    Bakery     53.191402
# 705  56bfdc38cd10422b286cc844                      Café     53.326687
# 706  52591bcc11d2b9d14c201e80                      Café     53.326589
# 707  5c52afc17564f7002c4ca56a                      None     53.330450
# 708  52dbb6bd498ecf6f49246671                      Café     53.176748
# 709  4fca2043e4b07c8e3ddba5e5                      Café     53.152993
# 710  52824a53498ed03744097ea9                      Café     53.170304
# 711  5cc7056b3abcaf0033ef11b1                    Bakery     53.223446
# 712  5b6c0e7ddff815002cff4d5d   Comfort Food Restaurant     53.173358
# 713  5afd98d9dff815002caf2c36                      Café     53.114585
# 714  51262022e4b0857bf36cdc73                      Café     53.114597
# 715  521a154111d29f14c0eb9412                      Café     53.096154
# 716  4e04a1cdb0fb3e6ecac4dbc7                      Café     53.149322
# 717  5184133f498ecac6e2f3c1b3            Ice Cream Shop     53.095741
# 718  4daad5d9ffcb4a686de71286                    Bakery     53.154408
# 719  4ceba9d9f1c6236ab10e71f0                    Bakery     53.163582
# 720  50a4f5587ab4bf157a5d644f                      Café     53.145561
# 721  54bd1699498ee6c3dd7db9c5                      Café     53.107177
#
#      location.lng
# 0        6.694292
# 1        6.664623
# 2        6.663512
# 3        6.664241
# 4        6.691201
# 5        6.660200
# 6        6.667349
# 7        6.725730
# 8        6.671627
# 9        6.675450
# 10       6.660195
# 11       6.994862
# 12       6.744713
# 13       6.666757
# 14       6.807156
# 15       6.794060
# 16       6.683630
# 17       6.844310
# 18       6.808229
# 19       6.763307
# 20       6.672503
# 21       6.785903
# 22       6.859591
# 23       6.726507
# 24       6.925098
# 25       6.808901
# 26       6.928575
# 27       6.808580
# 28       6.951050
# 29       6.930347
# ..            ...
# 692      8.586463
# 693      8.451228
# 694      8.581927
# 695      8.582404
# 696      8.578792
# 697      8.570824
# 698      8.571053
# 699      8.576568
# 700      8.585847
# 701      8.576444
# 702      8.576250
# 703      8.573310
# 704      8.557415
# 705      8.484967
# 706      8.485516
# 707      8.459330
# 708      8.475531
# 709      8.428613
# 710      8.623502
# 711      8.595418
# 712      8.618207
# 713      8.455487
# 714      8.455362
# 715      8.505147
# 716      8.308085
# 717      8.531327
# 718      8.243355
# 719      8.617300
# 720      8.223932
# 721      8.277374
#
# [722 rows x 5 columns]

# %%
#now we need to drop all data that wasnt in the original trade area borders:

#remove all values south of the southern border
df_clean3 = df_clean2[df_clean2['location.lat'] > 53.03]
print(df_clean3.shape)

#remove all values east of the border
df_clean3 = df_clean3[df_clean3['location.lng'] < 8.49]
print(df_clean3.shape)

#remove all values west of the border
df_clean3.rename(columns={"location.lat": "lat", "location.lng": "lng"},inplace=True)
df_clean3.drop(df_clean3[(df_clean3.lng < 7.21) & (df_clean3.lat < 53.32)].index, inplace=True)
df_clean3.drop(df_clean3[(df_clean3.lng < 7) & (df_clean3.lat < 53.53)].index, inplace=True)
print(df_clean3.shape)
# Out:
# (706, 5)
# (635, 5)
# (466, 5)

# %%
# lets check what categories we have, to exclude any asian restaurants:
df_clean3.groupby(['categories']).count()
# Out:
#                                           name   id  lat  lng
# categories
# American Restaurant                          1    1    1    1
# Asian Restaurant                             4    4    4    4
# BBQ Joint                                    3    3    3    3
# Bagel Shop                                   2    2    2    2
# Bakery                                       9    9    9    9
# Bar                                          6    6    6    6
# Bistro                                       2    2    2    2
# Breakfast Spot                               2    2    2    2
# Burger Joint                                 2    2    2    2
# Café                                       159  159  159  159
# Caribbean Restaurant                         1    1    1    1
# Chinese Restaurant                           9    9    9    9
# Cocktail Bar                                 4    4    4    4
# Coffee Shop                                  6    6    6    6
# Dessert Shop                                 1    1    1    1
# Diner                                        2    2    2    2
# Doner Restaurant                             1    1    1    1
# Dumpling Restaurant                          1    1    1    1
# Fast Food Restaurant                         2    2    2    2
# Fish & Chips Shop                            1    1    1    1
# Food                                         2    2    2    2
# Gastropub                                    6    6    6    6
# German Restaurant                           47   47   47   47
# Gluten-free Restaurant                       1    1    1    1
# Greek Restaurant                            31   31   31   31
# History Museum                               1    1    1    1
# Hotel                                       20   20   20   20
# Ice Cream Shop                              13   13   13   13
# Indian Restaurant                            2    2    2    2
# Italian Restaurant                          11   11   11   11
# Lounge                                       1    1    1    1
# Mediterranean Restaurant                     6    6    6    6
# Mexican Restaurant                           2    2    2    2
# Middle Eastern Restaurant                    1    1    1    1
# Mongolian Restaurant                         1    1    1    1
# Peruvian Restaurant                          1    1    1    1
# Pizza Place                                  1    1    1    1
# Pub                                          2    2    2    2
# Residential Building (Apartment / Condo)     1    1    1    1
# Restaurant                                  48   48   48   48
# Scandinavian Restaurant                      1    1    1    1
# Seafood Restaurant                          24   24   24   24
# Steakhouse                                   3    3    3    3
# Tapas Restaurant                             1    1    1    1
# Tea Room                                     2    2    2    2
# Turkish Restaurant                           1    1    1    1
# Vegetarian / Vegan Restaurant                1    1    1    1

# %%
# we can see fitting categrories: Asian Restaurant, Dumpling Restaurant, Chinese Restaurant, Mongolian Restaurant,
#df_clean4 = df_clean3[df_clean3['categories'] != ('Asian Restaurant' or 'Dumpling Restaurant' or 'Chinese Restaurant' or 'Mongolian Restaurant')]
df_clean3.drop(df_clean3[(df_clean3.categories == 'Asian Restaurant')].index, inplace=True)
df_clean3.drop(df_clean3[(df_clean3.categories == 'Chinese Restaurant')].index, inplace=True)
df_clean3.drop(df_clean3[(df_clean3.categories == 'Dumpling Restaurant')].index, inplace=True)
df_clean3.drop(df_clean3[(df_clean3.categories == 'Mongolian Restaurant')].index, inplace=True)
df_clean3.reset_index(inplace=True)
df_clean3 = df_clean3.loc[:, ['name', 'id', 'categories', 'lat', 'lng']]
df_cleaned = df_clean3.copy()
df_cleaned
# Out:
#                              name                        id  \
# 0     Restaurant Café Geflügelhof  55e2ffd5498ed6652fc8eb5d
# 1             Restaurant Zum Kaap  51f550cf498e29a9dc99986f
# 2              Restaurant Seehund  50521591e4b0d453755ceed3
# 3       Restaurant Austernfischer  4ebc17d3be7b329d90ba532d
# 4       Restaurant Zum Yachthafen  4ffed466e4b002ba9a0b971e
# 5                Restaurant Palée  513b9e25e4b02424670f5926
# 6              Restaurant Südhauk  599b0df4419a9e32cdaef1b0
# 7         Café Restaurant Ostland  4e69ecca1f6e1e74e3fb228b
# 8      Cafe Restaurant Alt Borkum  4ffee479e4b0092e51a67fe2
# 9       Café Restaurant Bar Alibi  555502a8498ea54200dd3155
# 450  Möbel Buss-Familien Café Bar  54bd1699498ee6c3dd7db9c5
#
#                    categories        lat       lng
# 0                        Café  53.591618  6.694292
# 1          Seafood Restaurant  53.593548  6.664623
# 2          Seafood Restaurant  53.588142  6.663512
# 3          Seafood Restaurant  53.589037  6.664241
# 4           German Restaurant  53.585113  6.691201
# 5                  Restaurant  53.590282  6.660200
# 6                  Restaurant  53.580980  6.667349
# 7           German Restaurant  53.604226  6.725730
# 8          Seafood Restaurant  53.587883  6.671627
# 9                   Gastropub  53.595657  6.675450
# 10                  Gastropub  53.587086  6.660195
# 11         Seafood Restaurant  53.674270  6.994862
# 12          German Restaurant  53.559410  6.744713
# 13   Mediterranean Restaurant  53.587128  6.666757
# 14                      Hotel  53.707723  7.141655
# 15                 Restaurant  53.703930  7.147124
# 16         Seafood Restaurant  53.708720  7.148301
# 17                 Restaurant  53.618303  7.159590
# 18                       None  53.705874  7.143951
# 19          Fish & Chips Shop  53.707606  7.147624
# 20          German Restaurant  53.610195  7.153481
# 21         Italian Restaurant  53.617153  7.155168
# 22         Seafood Restaurant  53.614586  7.151379
# 23                       None  53.617659  7.151544
# 24                 Restaurant  53.707603  7.138671
# 25          German Restaurant  53.706747  7.140247
# 26                       None  53.707374  7.139434
# 27                 Restaurant  53.706122  7.140759
# 28           Greek Restaurant  53.708159  7.138255
# 29                  BBQ Joint  53.705713  7.144025
# ..                        ...        ...       ...
# 421                      Café  53.139268  8.211282
# 422                      Café  53.131541  8.213388
# 423                      Café  53.134548  8.218694
# 424                      Café  53.142885  8.213123
# 425                      Café  53.139889  8.214193
# 426                      Café  53.144260  8.213537
# 427                      Café  53.144198  8.215018
# 428                      Café  53.141577  8.213718
# 429                      Café  53.126835  8.237923
# 430                      Café  53.577053  8.367889
# 431                      Café  53.598362  8.312444
# 432                      Café  53.580552  8.375290
# 433        Seafood Restaurant  53.472003  8.462546
# 434                    Bakery  53.490312  8.470115
# 435                      Café  53.486116  8.482930
# 436                     Hotel  53.484005  8.486690
# 437              Dessert Shop  53.485918  8.483418
# 438                       Bar  53.483487  8.484417
# 439                      Café  53.402127  8.451228
# 440                      Café  53.326687  8.484967
# 441                      Café  53.326589  8.485516
# 442                      None  53.330450  8.459330
# 443                      Café  53.176748  8.475531
# 444                      Café  53.152993  8.428613
# 445                      Café  53.114585  8.455487
# 446                      Café  53.114597  8.455362
# 447                      Café  53.149322  8.308085
# 448                    Bakery  53.154408  8.243355
# 449                      Café  53.145561  8.223932
# 450                      Café  53.107177  8.277374
#
# [451 rows x 5 columns]

# %% [markdown]
# Now we finally have it! Our clean dataframe of 451 restaurants that we can use for further analysis! Lets draw a map first, to visualize the data:

# %%
# starting a Folium map around the area:
map_rest = folium.Map(location=[53.23, 7.47], zoom_start=9)

# starting a list of points that mark the corner of the area
map_rest = [[53.53, 6.5], [53.24, 6.5], [53.24, 7.0], [53.32, 7.21]]

# draw points
for each in points:  
    map_rest.add_child(folium.CircleMarker(location=each,
    fill='true',
    radius = 6,
    popup= str(each),
    fill_color='blue',
    color = 'clear',
    fill_opacity=1))

# add lines between the points
folium.PolyLine(points, color="blue", weight=2.5, opacity=1).add_to(map_rest)    

# lets draw the map!
map_rest
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-218-a99672cab024> in <module>
#       7 # draw points
#       8 for each in points:
# ----> 9     map_rest.add_child(folium.CircleMarker(location=each,
#      10     fill='true',
#      11     radius = 6,
#
# AttributeError: 'list' object has no attribute 'add_child'

# %%
venues_map = folium.Map(location=[53.23, 7.47], zoom_start=9)


# add popular spots to the map as blue circle markers
for lat, lng in zip(df_cleaned.lat, df_cleaned.lng):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have all the data, lets look at finding a model that does what the original question was - how can we get an efficient and fair solution in distibuting the trade areas?
#
# We will use the power of machine learning here, namely three algorithms of unsupervised learning that are the most common clustering methods: k-means clustering, hierachical clustering, and DBSCAN clustering.

# %%
# we start with k-means clustering, in this case 5 clusters
from sklearn.cluster import KMeans

# we copy the dataframe
df_kmeans = df_cleaned.copy()

# arrange latitude and longitude in the correct format
df_latlng = df_kmeans[['lat', 'lng']]

# run k-means clustering with 5 clusters depending on latitude and longitude
kmeans = KMeans(n_clusters=5).fit(df_latlng)

#insert Clusters into the df
df_kmeans.insert(0, 'Cluster Labels', kmeans.labels_)

#lets see what this did:
df_kmeans.head(5)
# Out:
#    Cluster Labels                         name                        id  \
# 0               2  Restaurant Café Geflügelhof  55e2ffd5498ed6652fc8eb5d
# 1               2          Restaurant Zum Kaap  51f550cf498e29a9dc99986f
# 2               2           Restaurant Seehund  50521591e4b0d453755ceed3
# 3               2    Restaurant Austernfischer  4ebc17d3be7b329d90ba532d
# 4               2    Restaurant Zum Yachthafen  4ffed466e4b002ba9a0b971e
#
#            categories        lat       lng
# 0                Café  53.591618  6.694292
# 1  Seafood Restaurant  53.593548  6.664623
# 2  Seafood Restaurant  53.588142  6.663512
# 3  Seafood Restaurant  53.589037  6.664241
# 4   German Restaurant  53.585113  6.691201

# %% [markdown]
# lets put this into our same map with different colors for the clusters:

# %%
# same map, this time different colors based on cluster labels:
venues_kmeans = folium.Map(location=[53.23, 7.47], zoom_start=9)

# add markers to map
for lat, lng, cluster in zip(df_kmeans['lat'], df_kmeans['lng'], df_kmeans['Cluster Labels']):
    if cluster == 0:
        color = 'Red'
    elif cluster == 1:
        color = 'Blue'
    elif cluster == 2:
        color = 'Green'
    elif cluster == 3:
        color = 'Black' 
    elif cluster == 4:
        color = 'Orange'
    elif cluster == 5:
        color = 'pink' 
    elif cluster == 6:
        color = 'white' 
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.9,
        parse_html=False).add_to(venues_kmeans)  
    
venues_kmeans
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_kmeans.groupby(['Cluster Labels']).count()
# Out:
#                 name   id  categories  lat  lng
# Cluster Labels
# 0                 67   67          63   67   67
# 1                109  109         105  109  109
# 2                 25   25          25   25   25
# 3                137  137         131  137  137
# 4                113  113         110  113  113

# %% [markdown]
# our first cluster! At a first clange we can see that the island on the far left (Borkum) is rather far away from the rest, so the algorithm gives it its own cluster with only 25 restaurants. The rest seems understandable and logical, with some variance in it (67 min to 137 max), but 3 of the 5 rather close. Lets see the next algorithm:

# %%
#now Hierachical Clustering!
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import MinMaxScaler

# we copy the dataframe
df_hier = df_cleaned.copy()

# arrange latitude and longitude in the correct format
df_latlng = df_hier[['lat', 'lng']]

# we turn the values in a numpy array and normalize them:
x = df_latlng.values
min_max_scaler = MinMaxScaler()
feature_mtx = min_max_scaler.fit_transform(x)
feature_mtx [0:5]

# run agglomaritive hiercharical clustering with 5 clusters depending on latitude and longitude
agglom = AgglomerativeClustering(n_clusters = 5)
agglom.fit(feature_mtx)

#insert Clusters into the df
df_hier.insert(0, 'Cluster Labels', agglom.labels_)

#lets see what this did:
df_hier.head()
# Out:
#    Cluster Labels                         name                        id  \
# 0               0  Restaurant Café Geflügelhof  55e2ffd5498ed6652fc8eb5d
# 1               0          Restaurant Zum Kaap  51f550cf498e29a9dc99986f
# 2               0           Restaurant Seehund  50521591e4b0d453755ceed3
# 3               0    Restaurant Austernfischer  4ebc17d3be7b329d90ba532d
# 4               0    Restaurant Zum Yachthafen  4ffed466e4b002ba9a0b971e
#
#            categories        lat       lng
# 0                Café  53.591618  6.694292
# 1  Seafood Restaurant  53.593548  6.664623
# 2  Seafood Restaurant  53.588142  6.663512
# 3  Seafood Restaurant  53.589037  6.664241
# 4   German Restaurant  53.585113  6.691201

# %%
# same map, this time different colors based on cluster labels:
venues_hier = folium.Map(location=[53.23, 7.47], zoom_start=9)

for lat, lng, cluster in zip(df_hier['lat'], df_hier['lng'], df_hier['Cluster Labels']):
    if cluster == 0:
        color = 'Red'
    elif cluster == 1:
        color = 'Blue'
    elif cluster == 2:
        color = 'Green'
    elif cluster == 3:
        color = 'Black' 
    elif cluster == 4:
        color = 'Orange'
    elif cluster == 5:
        color = 'pink' 
    elif cluster == 6:
        color = 'white' 
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.9,
        parse_html=False).add_to(venues_hier)  
    
venues_hier
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_hier.groupby(['Cluster Labels']).count()
# Out:
#                 name   id  categories  lat  lng
# Cluster Labels
# 0                164  164         158  164  164
# 1                 88   88          86   88   88
# 2                 76   76          74   76   76
# 3                 64   64          60   64   64
# 4                 59   59          56   59   59

# %% [markdown]
# Here we can see, out little Island-Problem is solved, however this algorithm brings almost half of the map together in the red cluster, with a total of 164 restaurants, leaving only 59-88 restaurants in the other clusters. Thats a big lean towards the red cluster. Lets see what our last algorithm brings:

# %%
from sklearn.cluster import DBSCAN

# we copy the dataframe
df_DBS = df_cleaned.copy()

# arrange latitude and longitude in the correct format
df_latlng = df_DBS[['lat', 'lng']]

# run agglomaritive hiercharical clustering with 5 clusters depending on latitude and longitude
epsilon = 0.05
minimumSamples = 6
DBS = DBSCAN(eps=epsilon, min_samples=minimumSamples).fit(df_latlng)

#insert Clusters into the df
df_DBS.insert(0, 'Cluster Labels', DBS.labels_)

#lets see what this did:
df_DBS.head(5)
# Out:
#    Cluster Labels                         name                        id  \
# 0               0  Restaurant Café Geflügelhof  55e2ffd5498ed6652fc8eb5d
# 1               0          Restaurant Zum Kaap  51f550cf498e29a9dc99986f
# 2               0           Restaurant Seehund  50521591e4b0d453755ceed3
# 3               0    Restaurant Austernfischer  4ebc17d3be7b329d90ba532d
# 4               0    Restaurant Zum Yachthafen  4ffed466e4b002ba9a0b971e
#
#            categories        lat       lng
# 0                Café  53.591618  6.694292
# 1  Seafood Restaurant  53.593548  6.664623
# 2  Seafood Restaurant  53.588142  6.663512
# 3  Seafood Restaurant  53.589037  6.664241
# 4   German Restaurant  53.585113  6.691201

# %%
import random
# same map, this time different colors based on cluster labels:
venues_DBS = folium.Map(location=[53.23, 7.47], zoom_start=9)

list_colors=['Red', 'Blue','Green','Black', 'Orange','pink','white', 'Red', 'Blue','Green','Black', 'Orange','pink','white','Red', 'Blue','Green','Black', 'Orange','pink','white','Red', 'Blue','Green','Black', 'Orange','pink','white','Red', 'Blue','Green','Black', 'Orange','pink','white','Red', 'Blue','Green','Black', 'Orange','pink','white', 'grey']
      
for lat, lng, cluster in zip(df_DBS['lat'], df_DBS['lng'], df_DBS['Cluster Labels']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color=list_colors[cluster],
        fill=True,
        fill_color=list_colors[cluster],
        
        fill_opacity=0.9,
        parse_html=False).add_to(venues_DBS)
    
    
venues_DBS
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_DBS.groupby(['Cluster Labels']).count()
# Out:
#                 name   id  categories  lat  lng
# Cluster Labels
# -1               103  103         100  103  103
#  0                25   25          25   25   25
#  1                25   25          23   25   25
#  2                21   21          19   21   21
#  3                11   11          11   11   11
#  4                24   24          24   24   24
#  5                11   11          11   11   11
#  6                 7    7           7    7    7
#  7                11   11          10   11   11
#  8                22   22          19   22   22
#  9                23   23          22   23   23
#  10                9    9           9    9    9
#  11               18   18          16   18   18
#  12               15   15          14   15   15
#  13               20   20          19   20   20
#  14               29   29          29   29   29
#  15               13   13          13   13   13
#  16               50   50          49   50   50
#  17                8    8           8    8    8
#  18                6    6           6    6    6

# %% [markdown]
# Maybe the DBSCAN algorithm wasnt the correct one from the beginning to answer the stakeholders question, as it is designed to mark outliers and not include them in their clusters - thats not what we want, we want to have all restaurants attributed to one sales area! However this map does have its insights, showing the bigger accumulation of restaurants, so Hot-Spots for our sales team.

# %% [markdown]
# To summarize the initial insights from the three algorithms: k-means is marking one island as a sperate cluster, otherwise seems a solid base to start further investigations. The hierarchical clustering produces clusters of very uneven size, so thats not so optimal for our goal so find fair cluster sizes. The DBSCAN does help with interesting insights, however it does not answer the original question for this project.
#
# So, lets continue to see if we can get the k-means algorithm to get us closer to an answer! Lets start off by playing with the cluster size (maybe 4 or 6 cluster might help, its within the scope of the stakeholders question):

# %%
# we copy the code from above, but change to 4 clusters only:
df_kmeans2 = df_cleaned.copy()
df_latlng2 = df_kmeans2[['lat', 'lng']]
kmeans2 = KMeans(n_clusters=4).fit(df_latlng2)
df_kmeans2.insert(0, 'Cluster Labels', kmeans2.labels_)
venues_kmeans2 = folium.Map(location=[53.23, 7.47], zoom_start=9)
for lat, lng, cluster in zip(df_kmeans2['lat'], df_kmeans2['lng'], df_kmeans2['Cluster Labels']):
    if cluster == 0:
        color = 'Red'
    elif cluster == 1:
        color = 'Blue'
    elif cluster == 2:
        color = 'Green'
    elif cluster == 3:
        color = 'Black' 
    elif cluster == 4:
        color = 'Orange'
    elif cluster == 5:
        color = 'pink' 
    elif cluster == 6:
        color = 'white' 
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.9,
        parse_html=False).add_to(venues_kmeans2)    
venues_kmeans2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# lets see how many restaurants we have per cluster
df_kmeans2.groupby(['Cluster Labels']).count()
# Out:
#                 name   id  categories  lat  lng
# Cluster Labels
# 0                103  103          98  103  103
# 1                109  109         104  109  109
# 2                117  117         113  117  117
# 3                122  122         119  122  122

# %% [markdown]
# Thats a very even distribution, and gets rid of the "island-problem". Minimum 103 restaurants, maximum 122. That sounds workable when looking at fairness and efficiency. We have a possible solution here. But what happens when we have 6 clusters? Lets see:

# %%
# we copy the code from above, but change to 6 clusters:
df_kmeans3 = df_cleaned.copy()
df_latlng3 = df_kmeans3[['lat', 'lng']]
kmeans3 = KMeans(n_clusters=6).fit(df_latlng3)
df_kmeans3.insert(0, 'Cluster Labels', kmeans3.labels_)
venues_kmeans3 = folium.Map(location=[53.23, 7.47], zoom_start=9)
for lat, lng, cluster in zip(df_kmeans3['lat'], df_kmeans3['lng'], df_kmeans3['Cluster Labels']):
    if cluster == 0:
        color = 'Red'
    elif cluster == 1:
        color = 'Blue'
    elif cluster == 2:
        color = 'Green'
    elif cluster == 3:
        color = 'Black' 
    elif cluster == 4:
        color = 'Orange'
    elif cluster == 5:
        color = 'pink' 
    elif cluster == 6:
        color = 'white' 
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.9,
        parse_html=False).add_to(venues_kmeans3)    
venues_kmeans3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_kmeans3.groupby(['Cluster Labels']).count()
# Out:
#                 name   id  categories  lat  lng
# Cluster Labels
# 0                 69   69          67   69   69
# 1                 25   25          25   25   25
# 2                 93   93          90   93   93
# 3                102  102          98  102  102
# 4                 84   84          81   84   84
# 5                 78   78          73   78   78

# %% [markdown]
# That is offhand not a workable solution: it maintains the "island-problem", and min-max apart from the island is 69-102, so also not very fair. 6 Trade areas doesnt seem to be the solution.
#
# But if we look beyond the numbers and algorithms, the trip to the island seems to a two-day sales trip - a trip there would anyways not be combinable with other visits on the mainland (ferry is about 3 hours). Maybe we can look at assigning the island to another trade area / cluster, independent of the distance to the trade area? If we add the 25 restaurants to the second smallest cluster (69), we would be at 94, our min-max would be 78-102, which seems fair, and we would be back at our original (optimal) trade areas! OK, lets assign cluster label 1 to cluster 0:

# %%
# copy df
df_recluster = df_kmeans3.copy()

#replace 1's with 0's
df_recluster['Cluster Labels'].replace(to_replace=1,value=0, inplace=True)
df_recluster.groupby(['Cluster Labels']).count()
# Out:
#                 name   id  categories  lat  lng
# Cluster Labels
# 0                 94   94          92   94   94
# 2                 93   93          90   93   93
# 3                102  102          98  102  102
# 4                 84   84          81   84   84
# 5                 78   78          73   78   78

# %%
venues_kmeans4 = folium.Map(location=[53.23, 7.47], zoom_start=9)
for lat, lng, cluster in zip(df_recluster['lat'], df_recluster['lng'], df_recluster['Cluster Labels']):
    if cluster == 0:
        color = 'Red'
    elif cluster == 1:
        color = 'pink'
    elif cluster == 2:
        color = 'Green'
    elif cluster == 3:
        color = 'Black' 
    elif cluster == 4:
        color = 'Orange'
    elif cluster == 5:
        color = 'blue' 
    elif cluster == 6:
        color = 'white' 
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.9,
        parse_html=False).add_to(venues_kmeans4)    
venues_kmeans4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# And here we have it! An alternative solution with 5 clusters / sales regions we can recommend to the stakeholders.
#
# That means have 2 possible solutions within the parameters set, one with 4 trade areas and one with 5 trade areas.
#
# Let us present our findings now!
